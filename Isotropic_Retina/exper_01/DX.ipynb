# %%
import config as CONFIG
import sys
sys.path.append(CONFIG.GLOBAL_MODEL_PATH)
from models.mwunet import mwunet

from csbdeep.io import load_training_data
from csbdeep.utils import plot_history, plot_some
from matplotlib import pyplot as plt

# %% [markdown]
# # Load Data

# %%
(X,Y), (X_val,Y_val), axes = load_training_data(CONFIG.TRAIN_DATASET_PATH, validation_split=0.1, axes='SCYX', verbose=True)
# Out:
# number of training images:	 22852
# number of validation images:	 2539
# image size (2D):		 (128, 128)
# axes:				 SYXC
# channels in / out:		 2 / 2

# %% [markdown]
# # Define Model

# %%
model = mwunet(input_shape=Y.shape[1:], output_shape=X.shape[1:], 
                conv_kernel_size=5, n_conv_per_scale=2, n_filters_per_scale=[64, 128, 256])
model.model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Inputs (InputLayer)             [(None, 128, 128, 2) 0
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 64, 128, 2)   0           Inputs[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv (TFOpLambda)    (None, 64, 128, 2)   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 64, 128, 2)   0           Inputs[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_2 (Sli (None, 64, 64, 2)    0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_1 (TFOpLambda)  (None, 64, 128, 2)   0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_3 (Sli (None, 64, 64, 2)    0           tf.math.truediv_1[0][0]
# __________________________________________________________________________________________________
# tf.math.negative (TFOpLambda)   (None, 64, 64, 2)    0           tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_1 (TFOpLambda) (None, 64, 64, 2)    0           tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 64, 64, 2)    0           tf.__operators__.getitem_2[0][0]
#                                                                  tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None, 64, 64, 2)    0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 64, 64, 2)    0           tf.math.negative[0][0]
#                                                                  tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 64, 64, 2)    0           tf.math.negative_1[0][0]
#                                                                  tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None, 64, 64, 2)    0           tf.__operators__.getitem_2[0][0]
#                                                                  tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 64, 64, 2)    0           tf.__operators__.add[0][0]
#                                                                  tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None, 64, 64, 2)    0           tf.math.truediv_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 64, 64, 2)    0           tf.math.subtract[0][0]
#                                                                  tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 64, 64, 2)    0           tf.__operators__.add_5[0][0]
#                                                                  tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_3 (TFOpLambda) (None, 64, 64, 2)    0           tf.math.subtract_2[0][0]
#                                                                  tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 64, 64, 2)    0           tf.__operators__.add_1[0][0]
#                                                                  tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 64, 64, 2)    0           tf.__operators__.add_3[0][0]
#                                                                  tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 64, 64, 2)    0           tf.math.subtract_1[0][0]
#                                                                  tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 64, 64, 2)    0           tf.math.subtract_3[0][0]
#                                                                  tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 64, 64, 8)    0           tf.__operators__.add_2[0][0]
#                                                                  tf.__operators__.add_4[0][0]
#                                                                  tf.__operators__.add_6[0][0]
#                                                                  tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 64)   12864       tf.concat[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 64)   102464      activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64, 64, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_6 (Sli (None, 32, 64, 64)   0           dropout[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_2 (TFOpLambda)  (None, 32, 64, 64)   0           tf.__operators__.getitem_6[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_7 (Sli (None, 32, 64, 64)   0           dropout[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_8 (Sli (None, 32, 32, 64)   0           tf.math.truediv_2[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_3 (TFOpLambda)  (None, 32, 64, 64)   0           tf.__operators__.getitem_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_9 (Sli (None, 32, 32, 64)   0           tf.math.truediv_3[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_2 (TFOpLambda) (None, 32, 32, 64)   0           tf.__operators__.getitem_8[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_3 (TFOpLambda) (None, 32, 32, 64)   0           tf.__operators__.getitem_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None, 32, 32, 64)   0           tf.__operators__.getitem_8[0][0]
#                                                                  tf.__operators__.getitem_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_10 (Sl (None, 32, 32, 64)   0           tf.math.truediv_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_4 (TFOpLambda) (None, 32, 32, 64)   0           tf.math.negative_2[0][0]
#                                                                  tf.__operators__.getitem_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_13 (TFOpLa (None, 32, 32, 64)   0           tf.math.negative_3[0][0]
#                                                                  tf.__operators__.getitem_9[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_6 (TFOpLambda) (None, 32, 32, 64)   0           tf.__operators__.getitem_8[0][0]
#                                                                  tf.__operators__.getitem_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, 32, 32, 64)   0           tf.__operators__.add_8[0][0]
#                                                                  tf.__operators__.getitem_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_11 (Sl (None, 32, 32, 64)   0           tf.math.truediv_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_11 (TFOpLa (None, 32, 32, 64)   0           tf.math.subtract_4[0][0]
#                                                                  tf.__operators__.getitem_10[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_5 (TFOpLambda) (None, 32, 32, 64)   0           tf.__operators__.add_13[0][0]
#                                                                  tf.__operators__.getitem_10[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_7 (TFOpLambda) (None, 32, 32, 64)   0           tf.math.subtract_6[0][0]
#                                                                  tf.__operators__.getitem_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, 32, 32, 64)   0           tf.__operators__.add_9[0][0]
#                                                                  tf.__operators__.getitem_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_12 (TFOpLa (None, 32, 32, 64)   0           tf.__operators__.add_11[0][0]
#                                                                  tf.__operators__.getitem_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_14 (TFOpLa (None, 32, 32, 64)   0           tf.math.subtract_5[0][0]
#                                                                  tf.__operators__.getitem_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_15 (TFOpLa (None, 32, 32, 64)   0           tf.math.subtract_7[0][0]
#                                                                  tf.__operators__.getitem_11[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 32, 32, 256)  0           tf.__operators__.add_10[0][0]
#                                                                  tf.__operators__.add_12[0][0]
#                                                                  tf.__operators__.add_14[0][0]
#                                                                  tf.__operators__.add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 128)  819328      tf.concat_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 128)  409728      activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_12 (Sl (None, 16, 32, 128)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_4 (TFOpLambda)  (None, 16, 32, 128)  0           tf.__operators__.getitem_12[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_13 (Sl (None, 16, 32, 128)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_14 (Sl (None, 16, 16, 128)  0           tf.math.truediv_4[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_5 (TFOpLambda)  (None, 16, 32, 128)  0           tf.__operators__.getitem_13[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_15 (Sl (None, 16, 16, 128)  0           tf.math.truediv_5[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_4 (TFOpLambda) (None, 16, 16, 128)  0           tf.__operators__.getitem_14[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_5 (TFOpLambda) (None, 16, 16, 128)  0           tf.__operators__.getitem_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_16 (TFOpLa (None, 16, 16, 128)  0           tf.__operators__.getitem_14[0][0]
#                                                                  tf.__operators__.getitem_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_16 (Sl (None, 16, 16, 128)  0           tf.math.truediv_4[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_8 (TFOpLambda) (None, 16, 16, 128)  0           tf.math.negative_4[0][0]
#                                                                  tf.__operators__.getitem_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_21 (TFOpLa (None, 16, 16, 128)  0           tf.math.negative_5[0][0]
#                                                                  tf.__operators__.getitem_15[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_10 (TFOpLambda (None, 16, 16, 128)  0           tf.__operators__.getitem_14[0][0]
#                                                                  tf.__operators__.getitem_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_17 (TFOpLa (None, 16, 16, 128)  0           tf.__operators__.add_16[0][0]
#                                                                  tf.__operators__.getitem_16[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_17 (Sl (None, 16, 16, 128)  0           tf.math.truediv_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_19 (TFOpLa (None, 16, 16, 128)  0           tf.math.subtract_8[0][0]
#                                                                  tf.__operators__.getitem_16[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_9 (TFOpLambda) (None, 16, 16, 128)  0           tf.__operators__.add_21[0][0]
#                                                                  tf.__operators__.getitem_16[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_11 (TFOpLambda (None, 16, 16, 128)  0           tf.math.subtract_10[0][0]
#                                                                  tf.__operators__.getitem_16[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_18 (TFOpLa (None, 16, 16, 128)  0           tf.__operators__.add_17[0][0]
#                                                                  tf.__operators__.getitem_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_20 (TFOpLa (None, 16, 16, 128)  0           tf.__operators__.add_19[0][0]
#                                                                  tf.__operators__.getitem_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_22 (TFOpLa (None, 16, 16, 128)  0           tf.math.subtract_9[0][0]
#                                                                  tf.__operators__.getitem_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_23 (TFOpLa (None, 16, 16, 128)  0           tf.math.subtract_11[0][0]
#                                                                  tf.__operators__.getitem_17[0][0]
# __________________________________________________________________________________________________
# tf.concat_2 (TFOpLambda)        (None, 16, 16, 512)  0           tf.__operators__.add_18[0][0]
#                                                                  tf.__operators__.add_20[0][0]
#                                                                  tf.__operators__.add_22[0][0]
#                                                                  tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 256)  3277056     tf.concat_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 512)  3277312     activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 512)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 512)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_21 (Sl (None, 16, 16, 128)  0           dropout_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_22 (Sl (None, 16, 16, 128)  0           dropout_2[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_6 (TFOpLambda)  (None, 16, 16, 128)  0           tf.__operators__.getitem_21[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_7 (TFOpLambda)  (None, 16, 16, 128)  0           tf.__operators__.getitem_22[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_23 (Sl (None, 16, 16, 128)  0           dropout_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape (TFOpLambda) (4,)                 0           dropout_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_12 (TFOpLambda (None, 16, 16, 128)  0           tf.math.truediv_6[0][0]
#                                                                  tf.math.truediv_7[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_8 (TFOpLambda)  (None, 16, 16, 128)  0           tf.__operators__.getitem_23[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_24 (Sl (None, 16, 16, 128)  0           dropout_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_19 (Sl ()                   0           tf.compat.v1.shape[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_20 (Sl ()                   0           tf.compat.v1.shape[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_13 (TFOpLambda (None, 16, 16, 128)  0           tf.math.subtract_12[0][0]
#                                                                  tf.math.truediv_8[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_9 (TFOpLambda)  (None, 16, 16, 128)  0           tf.__operators__.getitem_24[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_14 (TFOpLambda (None, 16, 16, 128)  0           tf.math.truediv_6[0][0]
#                                                                  tf.math.truediv_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_18 (Sl ()                   0           tf.compat.v1.shape[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   ()                   0           tf.__operators__.getitem_19[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) ()                   0           tf.__operators__.getitem_20[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_24 (TFOpLa (None, 16, 16, 128)  0           tf.math.subtract_13[0][0]
#                                                                  tf.math.truediv_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_25 (TFOpLa (None, 16, 16, 128)  0           tf.math.subtract_14[0][0]
#                                                                  tf.math.truediv_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_26 (TFOpLa (None, 16, 16, 128)  0           tf.math.truediv_6[0][0]
#                                                                  tf.math.truediv_7[0][0]
# __________________________________________________________________________________________________
# tf.zeros (TFOpLambda)           (None, None, None, 1 0           tf.__operators__.getitem_18[0][0]
#                                                                  tf.math.multiply[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_1 (TFOpL (16, 16, 128, None)  0           tf.__operators__.add_24[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_15 (TFOpLambda (None, 16, 16, 128)  0           tf.__operators__.add_25[0][0]
#                                                                  tf.math.truediv_9[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_16 (TFOpLambda (None, 16, 16, 128)  0           tf.__operators__.add_26[0][0]
#                                                                  tf.math.truediv_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_27 (TFOpLa (None, 16, 16, 128)  0           tf.math.truediv_6[0][0]
#                                                                  tf.math.truediv_7[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose (TFOpLam (None, None, 128, No 0           tf.zeros[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 128, None)    0           tf.compat.v1.transpose_1[0][0]
#                                                                  tf.__operators__.getitem_18[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_2 (TFOpL (16, 16, 128, None)  0           tf.math.subtract_15[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_17 (TFOpLambda (None, 16, 16, 128)  0           tf.math.subtract_16[0][0]
#                                                                  tf.math.truediv_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_28 (TFOpLa (None, 16, 16, 128)  0           tf.__operators__.add_27[0][0]
#                                                                  tf.math.truediv_8[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add (TFOpL (None, None, 128, No 0           tf.compat.v1.transpose[0][0]
#                                                                  tf.reshape[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None, 128, None)    0           tf.compat.v1.transpose_2[0][0]
#                                                                  tf.__operators__.getitem_18[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_3 (TFOpL (16, 16, 128, None)  0           tf.math.subtract_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_29 (TFOpLa (None, 16, 16, 128)  0           tf.__operators__.add_28[0][0]
#                                                                  tf.math.truediv_9[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_1 (TFO (None, None, 128, No 0           tf.tensor_scatter_nd_add[0][0]
#                                                                  tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_2 (TFOpLambda)       (None, 128, None)    0           tf.compat.v1.transpose_3[0][0]
#                                                                  tf.__operators__.getitem_18[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_4 (TFOpL (16, 16, 128, None)  0           tf.__operators__.add_29[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_2 (TFO (None, None, 128, No 0           tf.tensor_scatter_nd_add_1[0][0]
#                                                                  tf.reshape_2[0][0]
# __________________________________________________________________________________________________
# tf.reshape_3 (TFOpLambda)       (None, 128, None)    0           tf.compat.v1.transpose_4[0][0]
#                                                                  tf.__operators__.getitem_18[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_3 (TFO (None, None, 128, No 0           tf.tensor_scatter_nd_add_2[0][0]
#                                                                  tf.reshape_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_5 (TFOpL (None, None, None, 1 0           tf.tensor_scatter_nd_add_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_30 (TFOpLa (None, 32, 32, 128)  0           tf.compat.v1.transpose_5[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  409728      tf.__operators__.add_30[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 256)  819456      activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 256)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_28 (Sl (None, 32, 32, 64)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_29 (Sl (None, 32, 32, 64)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_10 (TFOpLambda) (None, 32, 32, 64)   0           tf.__operators__.getitem_28[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_11 (TFOpLambda) (None, 32, 32, 64)   0           tf.__operators__.getitem_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_30 (Sl (None, 32, 32, 64)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_1 (TFOpLambd (4,)                 0           activation_7[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_18 (TFOpLambda (None, 32, 32, 64)   0           tf.math.truediv_10[0][0]
#                                                                  tf.math.truediv_11[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_12 (TFOpLambda) (None, 32, 32, 64)   0           tf.__operators__.getitem_30[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_31 (Sl (None, 32, 32, 64)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_26 (Sl ()                   0           tf.compat.v1.shape_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_27 (Sl ()                   0           tf.compat.v1.shape_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_19 (TFOpLambda (None, 32, 32, 64)   0           tf.math.subtract_18[0][0]
#                                                                  tf.math.truediv_12[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_13 (TFOpLambda) (None, 32, 32, 64)   0           tf.__operators__.getitem_31[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_20 (TFOpLambda (None, 32, 32, 64)   0           tf.math.truediv_10[0][0]
#                                                                  tf.math.truediv_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_25 (Sl ()                   0           tf.compat.v1.shape_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) ()                   0           tf.__operators__.getitem_26[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) ()                   0           tf.__operators__.getitem_27[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_31 (TFOpLa (None, 32, 32, 64)   0           tf.math.subtract_19[0][0]
#                                                                  tf.math.truediv_13[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_32 (TFOpLa (None, 32, 32, 64)   0           tf.math.subtract_20[0][0]
#                                                                  tf.math.truediv_12[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_33 (TFOpLa (None, 32, 32, 64)   0           tf.math.truediv_10[0][0]
#                                                                  tf.math.truediv_11[0][0]
# __________________________________________________________________________________________________
# tf.zeros_1 (TFOpLambda)         (None, None, None, 6 0           tf.__operators__.getitem_25[0][0]
#                                                                  tf.math.multiply_2[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_7 (TFOpL (32, 32, 64, None)   0           tf.__operators__.add_31[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_21 (TFOpLambda (None, 32, 32, 64)   0           tf.__operators__.add_32[0][0]
#                                                                  tf.math.truediv_13[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_22 (TFOpLambda (None, 32, 32, 64)   0           tf.__operators__.add_33[0][0]
#                                                                  tf.math.truediv_12[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_34 (TFOpLa (None, 32, 32, 64)   0           tf.math.truediv_10[0][0]
#                                                                  tf.math.truediv_11[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_6 (TFOpL (None, None, 64, Non 0           tf.zeros_1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_4 (TFOpLambda)       (None, 64, None)     0           tf.compat.v1.transpose_7[0][0]
#                                                                  tf.__operators__.getitem_25[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_8 (TFOpL (32, 32, 64, None)   0           tf.math.subtract_21[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_23 (TFOpLambda (None, 32, 32, 64)   0           tf.math.subtract_22[0][0]
#                                                                  tf.math.truediv_13[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_35 (TFOpLa (None, 32, 32, 64)   0           tf.__operators__.add_34[0][0]
#                                                                  tf.math.truediv_12[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_4 (TFO (None, None, 64, Non 0           tf.compat.v1.transpose_6[0][0]
#                                                                  tf.reshape_4[0][0]
# __________________________________________________________________________________________________
# tf.reshape_5 (TFOpLambda)       (None, 64, None)     0           tf.compat.v1.transpose_8[0][0]
#                                                                  tf.__operators__.getitem_25[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_9 (TFOpL (32, 32, 64, None)   0           tf.math.subtract_23[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_36 (TFOpLa (None, 32, 32, 64)   0           tf.__operators__.add_35[0][0]
#                                                                  tf.math.truediv_13[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_5 (TFO (None, None, 64, Non 0           tf.tensor_scatter_nd_add_4[0][0]
#                                                                  tf.reshape_5[0][0]
# __________________________________________________________________________________________________
# tf.reshape_6 (TFOpLambda)       (None, 64, None)     0           tf.compat.v1.transpose_9[0][0]
#                                                                  tf.__operators__.getitem_25[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_10 (TFOp (32, 32, 64, None)   0           tf.__operators__.add_36[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_6 (TFO (None, None, 64, Non 0           tf.tensor_scatter_nd_add_5[0][0]
#                                                                  tf.reshape_6[0][0]
# __________________________________________________________________________________________________
# tf.reshape_7 (TFOpLambda)       (None, 64, None)     0           tf.compat.v1.transpose_10[0][0]
#                                                                  tf.__operators__.getitem_25[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_7 (TFO (None, None, 64, Non 0           tf.tensor_scatter_nd_add_6[0][0]
#                                                                  tf.reshape_7[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_11 (TFOp (None, None, None, 6 0           tf.tensor_scatter_nd_add_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_37 (TFOpLa (None, 64, 64, 64)   0           tf.compat.v1.transpose_11[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 64)   102464      tf.__operators__.add_37[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 64)   102464      activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 4)    260         activation_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_35 (Sl (None, 64, 64, 1)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_36 (Sl (None, 64, 64, 1)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_14 (TFOpLambda) (None, 64, 64, 1)    0           tf.__operators__.getitem_35[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_15 (TFOpLambda) (None, 64, 64, 1)    0           tf.__operators__.getitem_36[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_37 (Sl (None, 64, 64, 1)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_2 (TFOpLambd (4,)                 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_24 (TFOpLambda (None, 64, 64, 1)    0           tf.math.truediv_14[0][0]
#                                                                  tf.math.truediv_15[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_16 (TFOpLambda) (None, 64, 64, 1)    0           tf.__operators__.getitem_37[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_38 (Sl (None, 64, 64, 1)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_33 (Sl ()                   0           tf.compat.v1.shape_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_34 (Sl ()                   0           tf.compat.v1.shape_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_25 (TFOpLambda (None, 64, 64, 1)    0           tf.math.subtract_24[0][0]
#                                                                  tf.math.truediv_16[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_17 (TFOpLambda) (None, 64, 64, 1)    0           tf.__operators__.getitem_38[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_26 (TFOpLambda (None, 64, 64, 1)    0           tf.math.truediv_14[0][0]
#                                                                  tf.math.truediv_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_32 (Sl ()                   0           tf.compat.v1.shape_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) ()                   0           tf.__operators__.getitem_33[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) ()                   0           tf.__operators__.getitem_34[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_38 (TFOpLa (None, 64, 64, 1)    0           tf.math.subtract_25[0][0]
#                                                                  tf.math.truediv_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_39 (TFOpLa (None, 64, 64, 1)    0           tf.math.subtract_26[0][0]
#                                                                  tf.math.truediv_16[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_40 (TFOpLa (None, 64, 64, 1)    0           tf.math.truediv_14[0][0]
#                                                                  tf.math.truediv_15[0][0]
# __________________________________________________________________________________________________
# tf.zeros_2 (TFOpLambda)         (None, None, None, 1 0           tf.__operators__.getitem_32[0][0]
#                                                                  tf.math.multiply_4[0][0]
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_13 (TFOp (64, 64, 1, None)    0           tf.__operators__.add_38[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_27 (TFOpLambda (None, 64, 64, 1)    0           tf.__operators__.add_39[0][0]
#                                                                  tf.math.truediv_17[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_28 (TFOpLambda (None, 64, 64, 1)    0           tf.__operators__.add_40[0][0]
#                                                                  tf.math.truediv_16[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_41 (TFOpLa (None, 64, 64, 1)    0           tf.math.truediv_14[0][0]
#                                                                  tf.math.truediv_15[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_12 (TFOp (None, None, 1, None 0           tf.zeros_2[0][0]
# __________________________________________________________________________________________________
# tf.reshape_8 (TFOpLambda)       (None, 1, None)      0           tf.compat.v1.transpose_13[0][0]
#                                                                  tf.__operators__.getitem_32[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_14 (TFOp (64, 64, 1, None)    0           tf.math.subtract_27[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_29 (TFOpLambda (None, 64, 64, 1)    0           tf.math.subtract_28[0][0]
#                                                                  tf.math.truediv_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_42 (TFOpLa (None, 64, 64, 1)    0           tf.__operators__.add_41[0][0]
#                                                                  tf.math.truediv_16[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_8 (TFO (None, None, 1, None 0           tf.compat.v1.transpose_12[0][0]
#                                                                  tf.reshape_8[0][0]
# __________________________________________________________________________________________________
# tf.reshape_9 (TFOpLambda)       (None, 1, None)      0           tf.compat.v1.transpose_14[0][0]
#                                                                  tf.__operators__.getitem_32[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_15 (TFOp (64, 64, 1, None)    0           tf.math.subtract_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_43 (TFOpLa (None, 64, 64, 1)    0           tf.__operators__.add_42[0][0]
#                                                                  tf.math.truediv_17[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_9 (TFO (None, None, 1, None 0           tf.tensor_scatter_nd_add_8[0][0]
#                                                                  tf.reshape_9[0][0]
# __________________________________________________________________________________________________
# tf.reshape_10 (TFOpLambda)      (None, 1, None)      0           tf.compat.v1.transpose_15[0][0]
#                                                                  tf.__operators__.getitem_32[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_16 (TFOp (64, 64, 1, None)    0           tf.__operators__.add_43[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_10 (TF (None, None, 1, None 0           tf.tensor_scatter_nd_add_9[0][0]
#                                                                  tf.reshape_10[0][0]
# __________________________________________________________________________________________________
# tf.reshape_11 (TFOpLambda)      (None, 1, None)      0           tf.compat.v1.transpose_16[0][0]
#                                                                  tf.__operators__.getitem_32[0][0]
# __________________________________________________________________________________________________
# tf.tensor_scatter_nd_add_11 (TF (None, None, 1, None 0           tf.tensor_scatter_nd_add_10[0][0]
#                                                                  tf.reshape_11[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_17 (TFOp (None, None, None, 1 0           tf.tensor_scatter_nd_add_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_44 (TFOpLa (None, 128, 128, 2)  0           Inputs[0][0]
#                                                                  tf.compat.v1.transpose_17[0][0]
# ==================================================================================================
# Total params: 9,333,124
# Trainable params: 9,333,124
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
history = model.train(X=Y, Y=X, validation_data=(Y_val, X_val),
                      train_epochs=200, train_batch_size=32,
                      train_learning_rate=0.001,
                      base_dir=CONFIG.CHECKPOINT_PATH,
                      name='DX',
                      train_checkpoint='DX.hdf5'
                      )
# Out:
# Epoch 1/200
# 715/715 [==============================] - 92s 111ms/step - loss: 0.0686 - mse: 0.0094 - val_loss: 0.0731 - val_mse: 0.0101
#
# Epoch 00001: val_loss improved from inf to 0.07306, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 2/200
# 715/715 [==============================] - 74s 103ms/step - loss: 0.0657 - mse: 0.0086 - val_loss: 0.0646 - val_mse: 0.0085
#
# Epoch 00002: val_loss improved from 0.07306 to 0.06457, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 3/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0643 - mse: 0.0082 - val_loss: 0.0639 - val_mse: 0.0082
#
# Epoch 00003: val_loss improved from 0.06457 to 0.06388, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 4/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0636 - mse: 0.0081 - val_loss: 0.0631 - val_mse: 0.0079
#
# Epoch 00004: val_loss improved from 0.06388 to 0.06305, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 5/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0633 - mse: 0.0080 - val_loss: 0.0627 - val_mse: 0.0079
#
# Epoch 00005: val_loss improved from 0.06305 to 0.06271, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 6/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0628 - mse: 0.0078 - val_loss: 0.0634 - val_mse: 0.0080
#
# Epoch 00006: val_loss did not improve from 0.06271
# Epoch 7/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0626 - mse: 0.0078 - val_loss: 0.0646 - val_mse: 0.0083
#
# Epoch 00007: val_loss did not improve from 0.06271
# Epoch 8/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0620 - mse: 0.0077 - val_loss: 0.0627 - val_mse: 0.0078
#
# Epoch 00008: val_loss improved from 0.06271 to 0.06267, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 9/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0620 - mse: 0.0076 - val_loss: 0.0632 - val_mse: 0.0079
#
# Epoch 00009: val_loss did not improve from 0.06267
# Epoch 10/200
# 715/715 [==============================] - 72s 101ms/step - loss: 0.0615 - mse: 0.0075 - val_loss: 0.0626 - val_mse: 0.0078
#
# Epoch 00010: val_loss improved from 0.06267 to 0.06258, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 11/200
# 715/715 [==============================] - 72s 101ms/step - loss: 0.0613 - mse: 0.0075 - val_loss: 0.0638 - val_mse: 0.0080
#
# Epoch 00011: val_loss did not improve from 0.06258
# Epoch 12/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0611 - mse: 0.0074 - val_loss: 0.0623 - val_mse: 0.0078
#
# Epoch 00012: val_loss improved from 0.06258 to 0.06227, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 13/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0608 - mse: 0.0074 - val_loss: 0.0626 - val_mse: 0.0078
#
# Epoch 00013: val_loss did not improve from 0.06227
# Epoch 14/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0606 - mse: 0.0073 - val_loss: 0.0652 - val_mse: 0.0084
#
# Epoch 00014: val_loss did not improve from 0.06227
# Epoch 15/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0604 - mse: 0.0073 - val_loss: 0.0648 - val_mse: 0.0083
#
# Epoch 00015: val_loss did not improve from 0.06227
# Epoch 16/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0602 - mse: 0.0072 - val_loss: 0.0643 - val_mse: 0.0083
#
# Epoch 00016: val_loss did not improve from 0.06227
# Epoch 17/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0600 - mse: 0.0072 - val_loss: 0.0622 - val_mse: 0.0077
#
# Epoch 00017: val_loss improved from 0.06227 to 0.06217, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 18/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0599 - mse: 0.0072 - val_loss: 0.0625 - val_mse: 0.0078
#
# Epoch 00018: val_loss did not improve from 0.06217
# Epoch 19/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0596 - mse: 0.0071 - val_loss: 0.0625 - val_mse: 0.0078
#
# Epoch 00019: val_loss did not improve from 0.06217
# Epoch 20/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0595 - mse: 0.0070 - val_loss: 0.0612 - val_mse: 0.0076
#
# Epoch 00020: val_loss improved from 0.06217 to 0.06124, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 21/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0592 - mse: 0.0070 - val_loss: 0.0621 - val_mse: 0.0077
#
# Epoch 00021: val_loss did not improve from 0.06124
# Epoch 22/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0590 - mse: 0.0069 - val_loss: 0.0620 - val_mse: 0.0077
#
# Epoch 00022: val_loss did not improve from 0.06124
# Epoch 23/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0586 - mse: 0.0069 - val_loss: 0.0618 - val_mse: 0.0077
#
# Epoch 00023: val_loss did not improve from 0.06124
# Epoch 24/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0585 - mse: 0.0068 - val_loss: 0.0623 - val_mse: 0.0078
#
# Epoch 00024: val_loss did not improve from 0.06124
# Epoch 25/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0583 - mse: 0.0068 - val_loss: 0.0614 - val_mse: 0.0076
#
# Epoch 00025: val_loss did not improve from 0.06124
# Epoch 26/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0570 - mse: 0.0065 - val_loss: 0.0613 - val_mse: 0.0075
#
# Epoch 00026: val_loss did not improve from 0.06124
# Epoch 27/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0567 - mse: 0.0064 - val_loss: 0.0615 - val_mse: 0.0075
#
# Epoch 00027: val_loss did not improve from 0.06124
# Epoch 28/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0564 - mse: 0.0064 - val_loss: 0.0606 - val_mse: 0.0074
#
# Epoch 00028: val_loss improved from 0.06124 to 0.06061, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 29/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0562 - mse: 0.0063 - val_loss: 0.0618 - val_mse: 0.0076
#
# Epoch 00029: val_loss did not improve from 0.06061
# Epoch 30/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0560 - mse: 0.0063 - val_loss: 0.0611 - val_mse: 0.0075
#
# Epoch 00030: val_loss did not improve from 0.06061
# Epoch 31/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0557 - mse: 0.0062 - val_loss: 0.0621 - val_mse: 0.0077
#
# Epoch 00031: val_loss did not improve from 0.06061
# Epoch 32/200
# 715/715 [==============================] - 74s 104ms/step - loss: 0.0555 - mse: 0.0062 - val_loss: 0.0601 - val_mse: 0.0074
#
# Epoch 00032: val_loss improved from 0.06061 to 0.06008, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 33/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0552 - mse: 0.0061 - val_loss: 0.0597 - val_mse: 0.0072
#
# Epoch 00033: val_loss improved from 0.06008 to 0.05971, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 34/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0550 - mse: 0.0061 - val_loss: 0.0606 - val_mse: 0.0073
#
# Epoch 00034: val_loss did not improve from 0.05971
# Epoch 35/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0549 - mse: 0.0060 - val_loss: 0.0594 - val_mse: 0.0071
#
# Epoch 00035: val_loss improved from 0.05971 to 0.05944, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 36/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0547 - mse: 0.0060 - val_loss: 0.0598 - val_mse: 0.0072
#
# Epoch 00036: val_loss did not improve from 0.05944
# Epoch 37/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0545 - mse: 0.0060 - val_loss: 0.0608 - val_mse: 0.0074
#
# Epoch 00037: val_loss did not improve from 0.05944
# Epoch 38/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0543 - mse: 0.0059 - val_loss: 0.0601 - val_mse: 0.0073
#
# Epoch 00038: val_loss did not improve from 0.05944
# Epoch 39/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0541 - mse: 0.0059 - val_loss: 0.0591 - val_mse: 0.0071
#
# Epoch 00039: val_loss improved from 0.05944 to 0.05913, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 40/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0539 - mse: 0.0058 - val_loss: 0.0590 - val_mse: 0.0071
#
# Epoch 00040: val_loss improved from 0.05913 to 0.05897, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 41/200
# 715/715 [==============================] - 73s 103ms/step - loss: 0.0537 - mse: 0.0058 - val_loss: 0.0594 - val_mse: 0.0072
#
# Epoch 00041: val_loss did not improve from 0.05897
# Epoch 42/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0536 - mse: 0.0058 - val_loss: 0.0595 - val_mse: 0.0072
#
# Epoch 00042: val_loss did not improve from 0.05897
# Epoch 43/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0533 - mse: 0.0057 - val_loss: 0.0602 - val_mse: 0.0073
#
# Epoch 00043: val_loss did not improve from 0.05897
# Epoch 44/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0532 - mse: 0.0057 - val_loss: 0.0596 - val_mse: 0.0072
#
# Epoch 00044: val_loss did not improve from 0.05897
# Epoch 45/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0531 - mse: 0.0057 - val_loss: 0.0593 - val_mse: 0.0071
#
# Epoch 00045: val_loss did not improve from 0.05897
# Epoch 46/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0524 - mse: 0.0056 - val_loss: 0.0585 - val_mse: 0.0070
#
# Epoch 00046: val_loss improved from 0.05897 to 0.05853, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 47/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0523 - mse: 0.0055 - val_loss: 0.0584 - val_mse: 0.0070
#
# Epoch 00047: val_loss improved from 0.05853 to 0.05836, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 48/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0522 - mse: 0.0055 - val_loss: 0.0582 - val_mse: 0.0069
#
# Epoch 00048: val_loss improved from 0.05836 to 0.05819, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 49/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0521 - mse: 0.0055 - val_loss: 0.0585 - val_mse: 0.0070
#
# Epoch 00049: val_loss did not improve from 0.05819
# Epoch 50/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0519 - mse: 0.0055 - val_loss: 0.0584 - val_mse: 0.0070
#
# Epoch 00050: val_loss did not improve from 0.05819
# Epoch 51/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0519 - mse: 0.0055 - val_loss: 0.0588 - val_mse: 0.0071
#
# Epoch 00051: val_loss did not improve from 0.05819
# Epoch 52/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0517 - mse: 0.0054 - val_loss: 0.0582 - val_mse: 0.0070
#
# Epoch 00052: val_loss did not improve from 0.05819
# Epoch 53/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0517 - mse: 0.0054 - val_loss: 0.0586 - val_mse: 0.0070
#
# Epoch 00053: val_loss did not improve from 0.05819
# Epoch 54/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0514 - mse: 0.0054 - val_loss: 0.0583 - val_mse: 0.0070
#
# Epoch 00054: val_loss did not improve from 0.05819
# Epoch 55/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0513 - mse: 0.0054 - val_loss: 0.0583 - val_mse: 0.0070
#
# Epoch 00055: val_loss did not improve from 0.05819
# Epoch 56/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0513 - mse: 0.0054 - val_loss: 0.0585 - val_mse: 0.0070
#
# Epoch 00056: val_loss did not improve from 0.05819
# Epoch 57/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0512 - mse: 0.0053 - val_loss: 0.0582 - val_mse: 0.0069
#
# Epoch 00057: val_loss did not improve from 0.05819
# Epoch 58/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0511 - mse: 0.0053 - val_loss: 0.0582 - val_mse: 0.0070
#
# Epoch 00058: val_loss improved from 0.05819 to 0.05817, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 59/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0511 - mse: 0.0053 - val_loss: 0.0579 - val_mse: 0.0069
#
# Epoch 00059: val_loss improved from 0.05817 to 0.05787, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 60/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0511 - mse: 0.0053 - val_loss: 0.0578 - val_mse: 0.0069
#
# Epoch 00060: val_loss improved from 0.05787 to 0.05784, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 61/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0510 - mse: 0.0053 - val_loss: 0.0578 - val_mse: 0.0068
#
# Epoch 00061: val_loss improved from 0.05784 to 0.05781, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 62/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0510 - mse: 0.0053 - val_loss: 0.0579 - val_mse: 0.0069
#
# Epoch 00062: val_loss did not improve from 0.05781
# Epoch 63/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0509 - mse: 0.0053 - val_loss: 0.0578 - val_mse: 0.0069
#
# Epoch 00063: val_loss did not improve from 0.05781
# Epoch 64/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0509 - mse: 0.0053 - val_loss: 0.0579 - val_mse: 0.0069
#
# Epoch 00064: val_loss did not improve from 0.05781
# Epoch 65/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0508 - mse: 0.0053 - val_loss: 0.0578 - val_mse: 0.0069
#
# Epoch 00065: val_loss improved from 0.05781 to 0.05776, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 66/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0508 - mse: 0.0053 - val_loss: 0.0578 - val_mse: 0.0069
#
# Epoch 00066: val_loss did not improve from 0.05776
# Epoch 67/200
# 715/715 [==============================] - 75s 105ms/step - loss: 0.0508 - mse: 0.0053 - val_loss: 0.0579 - val_mse: 0.0069
#
# Epoch 00067: val_loss did not improve from 0.05776
# Epoch 68/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0507 - mse: 0.0053 - val_loss: 0.0580 - val_mse: 0.0069
#
# Epoch 00068: val_loss did not improve from 0.05776
# Epoch 69/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0507 - mse: 0.0053 - val_loss: 0.0577 - val_mse: 0.0069
#
# Epoch 00069: val_loss improved from 0.05776 to 0.05772, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 70/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0506 - mse: 0.0052 - val_loss: 0.0578 - val_mse: 0.0069
#
# Epoch 00070: val_loss did not improve from 0.05772
# Epoch 71/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0506 - mse: 0.0052 - val_loss: 0.0576 - val_mse: 0.0069
#
# Epoch 00071: val_loss improved from 0.05772 to 0.05765, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 72/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0506 - mse: 0.0052 - val_loss: 0.0576 - val_mse: 0.0068
#
# Epoch 00072: val_loss improved from 0.05765 to 0.05758, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 73/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0505 - mse: 0.0052 - val_loss: 0.0577 - val_mse: 0.0069
#
# Epoch 00073: val_loss did not improve from 0.05758
# Epoch 74/200
# 715/715 [==============================] - 79s 111ms/step - loss: 0.0505 - mse: 0.0052 - val_loss: 0.0576 - val_mse: 0.0068
#
# Epoch 00074: val_loss did not improve from 0.05758
# Epoch 75/200
# 715/715 [==============================] - 74s 103ms/step - loss: 0.0505 - mse: 0.0052 - val_loss: 0.0580 - val_mse: 0.0069
#
# Epoch 00075: val_loss did not improve from 0.05758
# Epoch 76/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0505 - mse: 0.0052 - val_loss: 0.0576 - val_mse: 0.0068
#
# Epoch 00076: val_loss did not improve from 0.05758
# Epoch 77/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0504 - mse: 0.0052 - val_loss: 0.0576 - val_mse: 0.0069
#
# Epoch 00077: val_loss did not improve from 0.05758
# Epoch 78/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0503 - mse: 0.0052 - val_loss: 0.0576 - val_mse: 0.0068
#
# Epoch 00078: val_loss improved from 0.05758 to 0.05757, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 79/200
# 715/715 [==============================] - 73s 101ms/step - loss: 0.0502 - mse: 0.0052 - val_loss: 0.0577 - val_mse: 0.0069
#
# Epoch 00079: val_loss did not improve from 0.05757
# Epoch 80/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0502 - mse: 0.0052 - val_loss: 0.0575 - val_mse: 0.0068
#
# Epoch 00080: val_loss improved from 0.05757 to 0.05753, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 81/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0502 - mse: 0.0052 - val_loss: 0.0577 - val_mse: 0.0068
#
# Epoch 00081: val_loss did not improve from 0.05753
# Epoch 82/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0502 - mse: 0.0052 - val_loss: 0.0575 - val_mse: 0.0068
#
# Epoch 00082: val_loss did not improve from 0.05753
# Epoch 83/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0502 - mse: 0.0052 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00083: val_loss improved from 0.05753 to 0.05744, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 84/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0502 - mse: 0.0052 - val_loss: 0.0576 - val_mse: 0.0068
#
# Epoch 00084: val_loss did not improve from 0.05744
# Epoch 85/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0501 - mse: 0.0052 - val_loss: 0.0576 - val_mse: 0.0068
#
# Epoch 00085: val_loss did not improve from 0.05744
# Epoch 86/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0501 - mse: 0.0051 - val_loss: 0.0576 - val_mse: 0.0068
#
# Epoch 00086: val_loss did not improve from 0.05744
# Epoch 87/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0501 - mse: 0.0051 - val_loss: 0.0575 - val_mse: 0.0068
#
# Epoch 00087: val_loss did not improve from 0.05744
# Epoch 88/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0501 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00088: val_loss did not improve from 0.05744
# Epoch 89/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0500 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00089: val_loss improved from 0.05744 to 0.05740, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 90/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0500 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00090: val_loss improved from 0.05740 to 0.05738, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 91/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0500 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00091: val_loss did not improve from 0.05738
# Epoch 92/200
# 715/715 [==============================] - 70s 97ms/step - loss: 0.0500 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00092: val_loss improved from 0.05738 to 0.05737, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 93/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0500 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00093: val_loss did not improve from 0.05737
# Epoch 94/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0499 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00094: val_loss did not improve from 0.05737
# Epoch 95/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0499 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00095: val_loss did not improve from 0.05737
# Epoch 96/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0499 - mse: 0.0051 - val_loss: 0.0575 - val_mse: 0.0068
#
# Epoch 00096: val_loss did not improve from 0.05737
# Epoch 97/200
# 715/715 [==============================] - 70s 97ms/step - loss: 0.0499 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00097: val_loss did not improve from 0.05737
# Epoch 98/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0499 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00098: val_loss improved from 0.05737 to 0.05732, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 99/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0499 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00099: val_loss did not improve from 0.05732
# Epoch 100/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0499 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00100: val_loss did not improve from 0.05732
# Epoch 101/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0499 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00101: val_loss improved from 0.05732 to 0.05729, saving model to ./checkpoint\DX\DX.hdf5
# Epoch 102/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0499 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00102: val_loss did not improve from 0.05729
# Epoch 103/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00103: val_loss did not improve from 0.05729
# Epoch 104/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00104: val_loss did not improve from 0.05729
# Epoch 105/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00105: val_loss did not improve from 0.05729
# Epoch 106/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00106: val_loss did not improve from 0.05729
# Epoch 107/200
# 715/715 [==============================] - 74s 104ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00107: val_loss did not improve from 0.05729
# Epoch 108/200
# 715/715 [==============================] - 74s 103ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00108: val_loss did not improve from 0.05729
# Epoch 109/200
# 715/715 [==============================] - 74s 103ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00109: val_loss did not improve from 0.05729
# Epoch 110/200
# 715/715 [==============================] - 76s 106ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00110: val_loss did not improve from 0.05729
# Epoch 111/200
# 715/715 [==============================] - 79s 110ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00111: val_loss did not improve from 0.05729
# Epoch 112/200
# 715/715 [==============================] - 79s 110ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00112: val_loss did not improve from 0.05729
# Epoch 113/200
# 715/715 [==============================] - 78s 110ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00113: val_loss did not improve from 0.05729
# Epoch 114/200
# 715/715 [==============================] - 78s 110ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00114: val_loss did not improve from 0.05729
# Epoch 115/200
# 715/715 [==============================] - 78s 110ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0574 - val_mse: 0.0068
#
# Epoch 00115: val_loss did not improve from 0.05729
# Epoch 116/200
# 715/715 [==============================] - 78s 110ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00116: val_loss did not improve from 0.05729
# Epoch 117/200
# 715/715 [==============================] - 78s 110ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00117: val_loss did not improve from 0.05729
# Epoch 118/200
# 715/715 [==============================] - 77s 108ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00118: val_loss did not improve from 0.05729
# Epoch 119/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00119: val_loss did not improve from 0.05729
# Epoch 120/200
# 715/715 [==============================] - 77s 108ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00120: val_loss did not improve from 0.05729
# Epoch 121/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00121: val_loss did not improve from 0.05729
# Epoch 122/200
# 715/715 [==============================] - 75s 105ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00122: val_loss did not improve from 0.05729
# Epoch 123/200
# 715/715 [==============================] - 76s 106ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00123: val_loss did not improve from 0.05729
# Epoch 124/200
# 715/715 [==============================] - 74s 104ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00124: val_loss did not improve from 0.05729
# Epoch 125/200
# 715/715 [==============================] - 74s 104ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00125: val_loss did not improve from 0.05729
# Epoch 126/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00126: val_loss did not improve from 0.05729
# Epoch 127/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00127: val_loss did not improve from 0.05729
# Epoch 128/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00128: val_loss did not improve from 0.05729
# Epoch 129/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00129: val_loss did not improve from 0.05729
# Epoch 130/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00130: val_loss did not improve from 0.05729
# Epoch 131/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00131: val_loss did not improve from 0.05729
# Epoch 132/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00132: val_loss did not improve from 0.05729
# Epoch 133/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00133: val_loss did not improve from 0.05729
# Epoch 134/200
# 715/715 [==============================] - 78s 110ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00134: val_loss did not improve from 0.05729
# Epoch 135/200
# 715/715 [==============================] - 78s 110ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00135: val_loss did not improve from 0.05729
# Epoch 136/200
# 715/715 [==============================] - 78s 110ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00136: val_loss did not improve from 0.05729
# Epoch 137/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00137: val_loss did not improve from 0.05729
# Epoch 138/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00138: val_loss did not improve from 0.05729
# Epoch 139/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00139: val_loss did not improve from 0.05729
# Epoch 140/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00140: val_loss did not improve from 0.05729
# Epoch 141/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00141: val_loss did not improve from 0.05729
# Epoch 142/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00142: val_loss did not improve from 0.05729
# Epoch 143/200
# 715/715 [==============================] - 78s 109ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00143: val_loss did not improve from 0.05729
# Epoch 144/200
# 715/715 [==============================] - 76s 106ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00144: val_loss did not improve from 0.05729
# Epoch 145/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00145: val_loss did not improve from 0.05729
# Epoch 146/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00146: val_loss did not improve from 0.05729
# Epoch 147/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00147: val_loss did not improve from 0.05729
# Epoch 148/200
# 715/715 [==============================] - 73s 101ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00148: val_loss did not improve from 0.05729
# Epoch 149/200
# 715/715 [==============================] - 72s 101ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00149: val_loss did not improve from 0.05729
# Epoch 150/200
# 715/715 [==============================] - 73s 101ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00150: val_loss did not improve from 0.05729
# Epoch 151/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00151: val_loss did not improve from 0.05729
# Epoch 152/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00152: val_loss did not improve from 0.05729
# Epoch 153/200
# 715/715 [==============================] - 72s 101ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00153: val_loss did not improve from 0.05729
# Epoch 154/200
# 715/715 [==============================] - 69s 96ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00154: val_loss did not improve from 0.05729
# Epoch 155/200
# 715/715 [==============================] - 69s 96ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00155: val_loss did not improve from 0.05729
# Epoch 156/200
# 715/715 [==============================] - 69s 96ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00156: val_loss did not improve from 0.05729
# Epoch 157/200
# 715/715 [==============================] - 69s 96ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00157: val_loss did not improve from 0.05729
# Epoch 158/200
# 715/715 [==============================] - 70s 97ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00158: val_loss did not improve from 0.05729
# Epoch 159/200
# 715/715 [==============================] - 72s 100ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00159: val_loss did not improve from 0.05729
# Epoch 160/200
# 715/715 [==============================] - 72s 101ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00160: val_loss did not improve from 0.05729
# Epoch 161/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00161: val_loss did not improve from 0.05729
# Epoch 162/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00162: val_loss did not improve from 0.05729
# Epoch 163/200
# 715/715 [==============================] - 70s 98ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00163: val_loss did not improve from 0.05729
# Epoch 164/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00164: val_loss did not improve from 0.05729
# Epoch 165/200
# 715/715 [==============================] - 72s 100ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00165: val_loss did not improve from 0.05729
# Epoch 166/200
# 715/715 [==============================] - 71s 100ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00166: val_loss did not improve from 0.05729
# Epoch 167/200
# 715/715 [==============================] - 72s 101ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00167: val_loss did not improve from 0.05729
# Epoch 168/200
# 715/715 [==============================] - 72s 101ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00168: val_loss did not improve from 0.05729
# Epoch 169/200
# 715/715 [==============================] - 72s 101ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00169: val_loss did not improve from 0.05729
# Epoch 170/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00170: val_loss did not improve from 0.05729
# Epoch 171/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00171: val_loss did not improve from 0.05729
# Epoch 172/200
# 715/715 [==============================] - 71s 99ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00172: val_loss did not improve from 0.05729
# Epoch 173/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00173: val_loss did not improve from 0.05729
# Epoch 174/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00174: val_loss did not improve from 0.05729
# Epoch 175/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00175: val_loss did not improve from 0.05729
# Epoch 176/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00176: val_loss did not improve from 0.05729
# Epoch 177/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00177: val_loss did not improve from 0.05729
# Epoch 178/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00178: val_loss did not improve from 0.05729
# Epoch 179/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00179: val_loss did not improve from 0.05729
# Epoch 180/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00180: val_loss did not improve from 0.05729
# Epoch 181/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00181: val_loss did not improve from 0.05729
# Epoch 182/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00182: val_loss did not improve from 0.05729
# Epoch 183/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00183: val_loss did not improve from 0.05729
# Epoch 184/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00184: val_loss did not improve from 0.05729
# Epoch 185/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00185: val_loss did not improve from 0.05729
# Epoch 186/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00186: val_loss did not improve from 0.05729
# Epoch 187/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00187: val_loss did not improve from 0.05729
# Epoch 188/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00188: val_loss did not improve from 0.05729
# Epoch 189/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00189: val_loss did not improve from 0.05729
# Epoch 190/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00190: val_loss did not improve from 0.05729
# Epoch 191/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00191: val_loss did not improve from 0.05729
# Epoch 192/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00192: val_loss did not improve from 0.05729
# Epoch 193/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00193: val_loss did not improve from 0.05729
# Epoch 194/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00194: val_loss did not improve from 0.05729
# Epoch 195/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00195: val_loss did not improve from 0.05729
# Epoch 196/200
# 715/715 [==============================] - 73s 101ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00196: val_loss did not improve from 0.05729
# Epoch 197/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00197: val_loss did not improve from 0.05729
# Epoch 198/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00198: val_loss did not improve from 0.05729
# Epoch 199/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00199: val_loss did not improve from 0.05729
# Epoch 200/200
# 715/715 [==============================] - 73s 102ms/step - loss: 0.0498 - mse: 0.0051 - val_loss: 0.0573 - val_mse: 0.0068
#
# Epoch 00200: val_loss did not improve from 0.05729

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(24,5))
plot_history(history, ['loss', 'val_loss'], ['mse', 'val_mse'], ['lr'])
# Out:
# ['loss', 'lr', 'mse', 'val_loss', 'val_mse']

# %% [markdown]
# # Validation

# %%
plt.figure(figsize=(12,7))
predict_res = model.predict(Y_val[:5])
plot_some(Y_val[:5], X_val[:5], predict_res, pmax=99.5)
plt.suptitle('5 example validation patches\n'
             'top row: input(source), '
             'middle row: target(ground truth), '
             'bottom row: predicted from source.')
plt.show()
